# %%
from keras.applications import DenseNet121
import os
import numpy as np
import cv2
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.applications.imagenet_utils import decode_predictions
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Model Download

# %%
import tensorflow as tf
from keras import backend as K

config = tf.ConfigProto()
config.gpu_options.allow_growth=True
sess = tf.Session(config=config)
K.set_session(sess)

# %%
image_size = 221
resnet_conv = DenseNet121(weights='imagenet', include_top=False, input_shape=(image_size, image_size,3))

# %%
for layer in resnet_conv.layers[:-4]:     
    layer.trainable = False
for layer in resnet_conv.layers:
    print(layer, layer.trainable)
# Out:
# (<keras.engine.input_layer.InputLayer object at 0x7f8e0697aad0>, False)
# (<keras.layers.convolutional.ZeroPadding2D object at 0x7f8e0697ae90>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8e0697ac10>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8e0697aed0>, False)
# (<keras.layers.core.Activation object at 0x7f8e068c6810>, False)
# (<keras.layers.convolutional.ZeroPadding2D object at 0x7f8e06966fd0>, False)
# (<keras.layers.pooling.MaxPooling2D object at 0x7f8e0699b2d0>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8e06913910>, False)
# (<keras.layers.core.Activation object at 0x7f8e06913510>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8e0688fdd0>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8e0689b090>, False)
# (<keras.layers.core.Activation object at 0x7f8e0685a750>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8e04546e90>, False)
# (<keras.layers.merge.Concatenate object at 0x7f8e04574ed0>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8e045a9e90>, False)
# (<keras.layers.core.Activation object at 0x7f8e044f9610>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8e045045d0>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8e04499e90>, False)
# (<keras.layers.core.Activation object at 0x7f8e04445b10>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8df47f2f10>, False)
# (<keras.layers.merge.Concatenate object at 0x7f8df4798890>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8df4749d90>, False)
# (<keras.layers.core.Activation object at 0x7f8df4749ed0>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8df46d1d10>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8df46c4f50>, False)
# (<keras.layers.core.Activation object at 0x7f8df4615f90>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8df462fe50>, False)
# (<keras.layers.merge.Concatenate object at 0x7f8df46a0c50>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8df455a510>, False)
# (<keras.layers.core.Activation object at 0x7f8df455a550>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8df44fbe90>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8df454fdd0>, False)
# (<keras.layers.core.Activation object at 0x7f8df4529a10>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8df449bb90>, False)
# (<keras.layers.merge.Concatenate object at 0x7f8df4538a90>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8df43dded0>, False)
# (<keras.layers.core.Activation object at 0x7f8df4477cd0>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8df43f8c50>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8df43e8e90>, False)
# (<keras.layers.core.Activation object at 0x7f8df4338bd0>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8df42d2ad0>, False)
# (<keras.layers.merge.Concatenate object at 0x7f8df4340a50>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8df4282fd0>, False)
# (<keras.layers.core.Activation object at 0x7f8df428f8d0>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8df4202450>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8df4223e50>, False)
# (<keras.layers.core.Activation object at 0x7f8df41cefd0>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8df4140ad0>, False)
# (<keras.layers.merge.Concatenate object at 0x7f8df414f690>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8e0699bad0>, False)
# (<keras.layers.core.Activation object at 0x7f8df416d510>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8df411ed10>, False)
# (<keras.layers.pooling.AveragePooling2D object at 0x7f8df4081fd0>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8df4061fd0>, False)
# (<keras.layers.core.Activation object at 0x7f8df4051fd0>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8de278c310>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8de275ef50>, False)
# (<keras.layers.core.Activation object at 0x7f8de26e4b90>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8de267d990>, False)
# (<keras.layers.merge.Concatenate object at 0x7f8de276f9d0>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8de26aebd0>, False)
# (<keras.layers.core.Activation object at 0x7f8de26bc650>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8de262c410>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8de25d1dd0>, False)
# (<keras.layers.core.Activation object at 0x7f8de257ff50>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8de2572a90>, False)
# (<keras.layers.merge.Concatenate object at 0x7f8de2500650>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8de251e310>, False)
# (<keras.layers.core.Activation object at 0x7f8de2442b90>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8de244fb50>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8de24b3e50>, False)
# (<keras.layers.core.Activation object at 0x7f8de238fad0>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8de23ab990>, False)
# (<keras.layers.merge.Concatenate object at 0x7f8de2419990>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8de235ba90>, False)
# (<keras.layers.core.Activation object at 0x7f8de22cce90>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8de227ed50>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8de22dde90>, False)
# (<keras.layers.core.Activation object at 0x7f8de22a8ed0>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8de21e0f50>, False)
# (<keras.layers.merge.Concatenate object at 0x7f8de22199d0>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8de216db10>, False)
# (<keras.layers.core.Activation object at 0x7f8de216dad0>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8de217aa90>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8de215dd90>, False)
# (<keras.layers.core.Activation object at 0x7f8de20c4b90>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8de20908d0>, False)
# (<keras.layers.merge.Concatenate object at 0x7f8de2053750>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8de2003a10>, False)
# (<keras.layers.core.Activation object at 0x7f8de1ff3dd0>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8de1fa1c10>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8de1f83dd0>, False)
# (<keras.layers.core.Activation object at 0x7f8de1f5c4d0>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8de1e8af90>, False)
# (<keras.layers.merge.Concatenate object at 0x7f8de1ec3fd0>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8de1e0fa50>, False)
# (<keras.layers.core.Activation object at 0x7f8de1e0fa10>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8de1dbf150>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8de1e02cd0>, False)
# (<keras.layers.core.Activation object at 0x7f8de1d60950>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8de1d7b750>, False)
# (<keras.layers.merge.Concatenate object at 0x7f8de1dea790>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8de1d2af90>, False)
# (<keras.layers.core.Activation object at 0x7f8de1c9dd10>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8de1c4d8d0>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8de1cafd10>, False)
# (<keras.layers.core.Activation object at 0x7f8de1c09450>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8de1bb5dd0>, False)
# (<keras.layers.merge.Concatenate object at 0x7f8de1becf10>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8de1abd990>, False)
# (<keras.layers.core.Activation object at 0x7f8de1abd950>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8de1af1410>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8de1b30c10>, False)
# (<keras.layers.core.Activation object at 0x7f8de1a07890>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8de1a26750>, False)
# (<keras.layers.merge.Concatenate object at 0x7f8de1a96750>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8de19e7350>, False)
# (<keras.layers.core.Activation object at 0x7f8de197a790>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8de195b890>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8de195bf50>, False)
# (<keras.layers.core.Activation object at 0x7f8de1860d50>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8de1896d90>, False)
# (<keras.layers.merge.Concatenate object at 0x7f8de17e3910>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8de17e3a90>, False)
# (<keras.layers.core.Activation object at 0x7f8de17d5c90>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8de17f2750>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8de17f2210>, False)
# (<keras.layers.core.Activation object at 0x7f8de170c450>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8de1724e50>, False)
# (<keras.layers.merge.Concatenate object at 0x7f8de16bce50>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8de1665e90>, False)
# (<keras.layers.core.Activation object at 0x7f8de1600d50>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8de1600fd0>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8de1621850>, False)
# (<keras.layers.core.Activation object at 0x7f8de1509dd0>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8de1541e50>, False)
# (<keras.layers.merge.Concatenate object at 0x7f8de148c9d0>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8df4061510>, False)
# (<keras.layers.core.Activation object at 0x7f8de148cb50>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8de14982d0>, False)
# (<keras.layers.pooling.AveragePooling2D object at 0x7f8de147ed50>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8de13d5a50>, False)
# (<keras.layers.core.Activation object at 0x7f8de13d59d0>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8de13c6d10>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8de1380e10>, False)
# (<keras.layers.core.Activation object at 0x7f8de131f9d0>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8de133c790>, False)
# (<keras.layers.merge.Concatenate object at 0x7f8de13ab810>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8de12e9fd0>, False)
# (<keras.layers.core.Activation object at 0x7f8de125dd90>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8de120abd0>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8de126cd90>, False)
# (<keras.layers.core.Activation object at 0x7f8de11c8490>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8de1177f90>, False)
# (<keras.layers.merge.Concatenate object at 0x7f8de11affd0>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8de10fca10>, False)
# (<keras.layers.core.Activation object at 0x7f8de10fc9d0>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8de10af150>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8de10edc90>, False)
# (<keras.layers.core.Activation object at 0x7f8de0fc8910>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8de0fe6810>, False)
# (<keras.layers.merge.Concatenate object at 0x7f8de1059790>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8de0f96ed0>, False)
# (<keras.layers.core.Activation object at 0x7f8de0f96bd0>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8de0f3a8d0>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8de0f19cd0>, False)
# (<keras.layers.core.Activation object at 0x7f8de0ef3450>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8de0e25d90>, False)
# (<keras.layers.merge.Concatenate object at 0x7f8de0e5ced0>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8de0dab950>, False)
# (<keras.layers.core.Activation object at 0x7f8de0dab910>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8de0d5b350>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8de0d9cbd0>, False)
# (<keras.layers.core.Activation object at 0x7f8de0cf4850>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8de0c92590>, False)
# (<keras.layers.merge.Concatenate object at 0x7f8de0d02890>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8de0c42c90>, False)
# (<keras.layers.core.Activation object at 0x7f8de0c42b90>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8de0c35990>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8de0be3790>, False)
# (<keras.layers.core.Activation object at 0x7f8de0b8db50>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8de0b2f1d0>, False)
# (<keras.layers.merge.Concatenate object at 0x7f8de0ac9d10>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8de0b00d10>, False)
# (<keras.layers.core.Activation object at 0x7f8de0a4e890>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8de0a5c810>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8de0a41f50>, False)
# (<keras.layers.core.Activation object at 0x7f8de09a1610>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8de0940690>, False)
# (<keras.layers.merge.Concatenate object at 0x7f8de0a295d0>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8de092bd10>, False)
# (<keras.layers.core.Activation object at 0x7f8de096bcd0>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8de088d710>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8de08dbe90>, False)
# (<keras.layers.core.Activation object at 0x7f8de08b7d90>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8de07daf50>, False)
# (<keras.layers.merge.Concatenate object at 0x7f8de07f4c10>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8de082add0>, False)
# (<keras.layers.core.Activation object at 0x7f8de07787d0>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8de0716dd0>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8de0768e90>, False)
# (<keras.layers.core.Activation object at 0x7f8de0642550>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8de0666a10>, False)
# (<keras.layers.merge.Concatenate object at 0x7f8de06d5550>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8de0613cd0>, False)
# (<keras.layers.core.Activation object at 0x7f8de0589dd0>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8de0597ed0>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8de05b94d0>, False)
# (<keras.layers.core.Activation object at 0x7f8de04f8c10>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8de04d9bd0>, False)
# (<keras.layers.merge.Concatenate object at 0x7f8de0424750>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8de04248d0>, False)
# (<keras.layers.core.Activation object at 0x7f8de0416b50>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8de0431590>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8de0431050>, False)
# (<keras.layers.core.Activation object at 0x7f8de0352550>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8de0368e50>, False)
# (<keras.layers.merge.Concatenate object at 0x7f8de02bfb10>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8de0280c90>, False)
# (<keras.layers.core.Activation object at 0x7f8de02b8890>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8de0245dd0>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8de0245890>, False)
# (<keras.layers.core.Activation object at 0x7f8de01b2150>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8de0184c90>, False)
# (<keras.layers.merge.Concatenate object at 0x7f8de00c2810>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8de00c2990>, False)
# (<keras.layers.core.Activation object at 0x7f8de0133c10>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8de00d3650>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8de00d3110>, False)
# (<keras.layers.core.Activation object at 0x7f8de006f610>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8daffc6f10>, False)
# (<keras.layers.merge.Concatenate object at 0x7f8daffa0bd0>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8daff5fd50>, False)
# (<keras.layers.core.Activation object at 0x7f8daff12950>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8daff20e50>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8daff20950>, False)
# (<keras.layers.core.Activation object at 0x7f8dafe28d50>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8dafe5ad50>, False)
# (<keras.layers.merge.Concatenate object at 0x7f8dafdaf8d0>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8dafdafa50>, False)
# (<keras.layers.core.Activation object at 0x7f8dafda1cd0>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8dafdbd710>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8dafdbd1d0>, False)
# (<keras.layers.core.Activation object at 0x7f8dafcd5410>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8dafcebfd0>, False)
# (<keras.layers.merge.Concatenate object at 0x7f8dafc05f10>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8dafc05e10>, False)
# (<keras.layers.core.Activation object at 0x7f8dafbe9890>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8dafbc8f90>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8dafbc8a10>, False)
# (<keras.layers.core.Activation object at 0x7f8dafb341d0>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8dafb05e10>, False)
# (<keras.layers.merge.Concatenate object at 0x7f8dafa56990>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8dafa56b10>, False)
# (<keras.layers.core.Activation object at 0x7f8dafa46d10>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8dafa637d0>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8dafa63290>, False)
# (<keras.layers.core.Activation object at 0x7f8daf9fc4d0>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8daf993ed0>, False)
# (<keras.layers.merge.Concatenate object at 0x7f8daf8d5f10>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8daf97b650>, False)
# (<keras.layers.core.Activation object at 0x7f8daf88c8d0>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8daf8edfd0>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8daf8edad0>, False)
# (<keras.layers.core.Activation object at 0x7f8daf7f9f90>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8daf830ed0>, False)
# (<keras.layers.merge.Concatenate object at 0x7f8daf77ca50>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8daf77cbd0>, False)
# (<keras.layers.core.Activation object at 0x7f8daf76edd0>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8daf709890>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8daf709350>, False)
# (<keras.layers.core.Activation object at 0x7f8daf6a4590>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8daf6baf90>, False)
# (<keras.layers.merge.Concatenate object at 0x7f8daf580fd0>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8daf6276d0>, False)
# (<keras.layers.core.Activation object at 0x7f8daf5bbcd0>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8daf59bf10>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8daf59bb90>, False)
# (<keras.layers.core.Activation object at 0x7f8daf4dc9d0>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8daf4ec9d0>, False)
# (<keras.layers.merge.Concatenate object at 0x7f8daf428b10>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8daf428c90>, False)
# (<keras.layers.core.Activation object at 0x7f8daf418e90>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8daf436950>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8daf3d8110>, False)
# (<keras.layers.core.Activation object at 0x7f8daf34f0d0>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8daf368d50>, False)
# (<keras.layers.merge.Concatenate object at 0x7f8daf2a0f10>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8daf2cf7d0>, False)
# (<keras.layers.core.Activation object at 0x7f8daf2b5ed0>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8daf251110>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8daf265d10>, False)
# (<keras.layers.core.Activation object at 0x7f8daf184a90>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8daf194a90>, False)
# (<keras.layers.merge.Concatenate object at 0x7f8daf0d1bd0>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8daf0d1d50>, False)
# (<keras.layers.core.Activation object at 0x7f8daf0c4f50>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8daf0e09d0>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8daf0801d0>, False)
# (<keras.layers.core.Activation object at 0x7f8daf079710>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8daf012e10>, False)
# (<keras.layers.merge.Concatenate object at 0x7f8daef47bd0>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8daeff98d0>, False)
# (<keras.layers.core.Activation object at 0x7f8daef5df90>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8daef790d0>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8daef0ae10>, False)
# (<keras.layers.core.Activation object at 0x7f8daeeabb50>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8daeeb9b50>, False)
# (<keras.layers.merge.Concatenate object at 0x7f8daebeeed0>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8de1453f50>, False)
# (<keras.layers.core.Activation object at 0x7f8daee05bd0>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8daeba9410>, False)
# (<keras.layers.pooling.AveragePooling2D object at 0x7f8daebffb50>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8daeb52390>, False)
# (<keras.layers.core.Activation object at 0x7f8daeb52f50>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8daeac2d50>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8daeaf1510>, False)
# (<keras.layers.core.Activation object at 0x7f8daeaab490>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8dae9d8ed0>, False)
# (<keras.layers.merge.Concatenate object at 0x7f8daea0ef50>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8dae95f9d0>, False)
# (<keras.layers.core.Activation object at 0x7f8dae95f990>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8dae90e150>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8dae950c50>, False)
# (<keras.layers.core.Activation object at 0x7f8dae8ac8d0>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8dae849610>, False)
# (<keras.layers.merge.Concatenate object at 0x7f8dae937790>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8dae87bed0>, False)
# (<keras.layers.core.Activation object at 0x7f8dae87bbd0>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8dae79c810>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8dae7fdc90>, False)
# (<keras.layers.core.Activation object at 0x7f8dae747c90>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8dae686dd0>, False)
# (<keras.layers.merge.Concatenate object at 0x7f8dae73ad90>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8dae609910>, False)
# (<keras.layers.core.Activation object at 0x7f8dae6098d0>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8dae63d350>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8dae67cfd0>, False)
# (<keras.layers.core.Activation object at 0x7f8dae555810>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8dae576710>, False)
# (<keras.layers.merge.Concatenate object at 0x7f8dae5e2690>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8dae532510>, False)
# (<keras.layers.core.Activation object at 0x7f8dae523b10>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8dae4457d0>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8dae497f10>, False)
# (<keras.layers.core.Activation object at 0x7f8dae46eb90>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8dae3930d0>, False)
# (<keras.layers.merge.Concatenate object at 0x7f8dae3aec90>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8dae3e7cd0>, False)
# (<keras.layers.core.Activation object at 0x7f8dae330850>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8dae2cfdd0>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8dae323f10>, False)
# (<keras.layers.core.Activation object at 0x7f8dae27f5d0>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8dae21f490>, False)
# (<keras.layers.merge.Concatenate object at 0x7f8dae28c790>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8dae1da490>, False)
# (<keras.layers.core.Activation object at 0x7f8dae1cca90>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8dae171690>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8dae1bfe50>, False)
# (<keras.layers.core.Activation object at 0x7f8dae11a890>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8dae040f50>, False)
# (<keras.layers.merge.Concatenate object at 0x7f8dae058c10>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8dae090d90>, False)
# (<keras.layers.core.Activation object at 0x7f8dadfdd790>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8dadffad10>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8dadfcee50>, False)
# (<keras.layers.core.Activation object at 0x7f8dadf26510>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8dadec6a50>, False)
# (<keras.layers.merge.Concatenate object at 0x7f8dadfb4490>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8dade84410>, False)
# (<keras.layers.core.Activation object at 0x7f8dadef3a10>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8dade76e90>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8dade69d90>, False)
# (<keras.layers.core.Activation object at 0x7f8daddc3750>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8dadd55e90>, False)
# (<keras.layers.merge.Concatenate object at 0x7f8dadd05f50>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8daddb9cd0>, False)
# (<keras.layers.core.Activation object at 0x7f8dadcf5f50>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8dadc91650>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8dadca1f50>, False)
# (<keras.layers.core.Activation object at 0x7f8dadc2fc10>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8dadbc7fd0>, False)
# (<keras.layers.merge.Concatenate object at 0x7f8dadb62b90>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8dadba2b10>, False)
# (<keras.layers.core.Activation object at 0x7f8dadb16790>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8dadb24c90>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8dadac4490>, False)
# (<keras.layers.core.Activation object at 0x7f8dada7dfd0>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8dada61d10>, False)
# (<keras.layers.merge.Concatenate object at 0x7f8dad9b1710>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8dad9b1890>, False)
# (<keras.layers.core.Activation object at 0x7f8dad9a5e10>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8dad9bf510>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8dad9bf110>, False)
# (<keras.layers.core.Activation object at 0x7f8dad8dc510>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8dad8f0e10>, False)
# (<keras.layers.merge.Concatenate object at 0x7f8dad80ac50>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8dad84acd0>, False)
# (<keras.layers.core.Activation object at 0x7f8dad83c850>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8dad7cad90>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8dad7ca850>, False)
# (<keras.layers.core.Activation object at 0x7f8dad734f50>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8dad704c50>, False)
# (<keras.layers.merge.Concatenate object at 0x7f8dad64c7d0>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8dad64c950>, False)
# (<keras.layers.core.Activation object at 0x7f8dad6bebd0>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8dad65b5d0>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8dad65b0d0>, False)
# (<keras.layers.core.Activation object at 0x7f8dad5f45d0>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8dad588ed0>, False)
# (<keras.layers.merge.Concatenate object at 0x7f8dad564b90>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8dad524d10>, False)
# (<keras.layers.core.Activation object at 0x7f8dad4d7910>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8dad4e4e50>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8dad4e4910>, False)
# (<keras.layers.core.Activation object at 0x7f8dad3d41d0>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8dad426d10>, False)
# (<keras.layers.merge.Concatenate object at 0x7f8dad372890>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8dad372a10>, False)
# (<keras.layers.core.Activation object at 0x7f8dad364c90>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f8dad3016d0>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8dad301290>, False)
# (<keras.layers.core.Activation object at 0x7f8dad29b3d0>, True)
# (<keras.layers.convolutional.Conv2D object at 0x7f8dad2b1f90>, True)
# (<keras.layers.merge.Concatenate object at 0x7f8dad20ec10>, True)
# (<keras.layers.normalization.BatchNormalization object at 0x7f8daeb0fd50>, True)

# %% [markdown]
# ## Creating a new Model

# %%
from keras import models
from keras import layers
from keras import optimizers
from keras.callbacks import EarlyStopping

early_stop = EarlyStopping(monitor='val_loss', min_delta=0, patience=3, verbose=1, mode='auto')


# Create the model
model = models.Sequential()
 
# Add the vgg convolutional base model
model.add(resnet_conv)
 
# Add new layers
model.add(layers.Flatten())
model.add(layers.Dense(1024, activation='relu'))
model.add(layers.Dropout(0.75))
model.add(layers.Dense(2, activation='softmax'))
 
# Show a summary of the model. Check the number of trainable parameters
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# densenet121 (Model)          (None, 7, 7, 1024)        7037504
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 50176)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              51381248
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 2050
# =================================================================
# Total params: 58,420,802
# Trainable params: 51,422,210
# Non-trainable params: 6,998,592
# _________________________________________________________________

# %% [markdown]
# ## Setup data generators

# %%
from keras.preprocessing.image import ImageDataGenerator


train_datagen = ImageDataGenerator(
      rescale=1./255,
      rotation_range=20,
      width_shift_range=0.2,
      height_shift_range=0.2,
      horizontal_flip=True,
      fill_mode='nearest')
 
validation_datagen = ImageDataGenerator(rescale=1./255)
 
# Change the batchsize according to your system RAM
train_batchsize = 50
val_batchsize = 10
 
train_generator = train_datagen.flow_from_directory(
        '../../data/deep_learn/train/',
        target_size=(image_size, image_size),
        batch_size=train_batchsize,
        class_mode='categorical')
 
validation_generator = validation_datagen.flow_from_directory(
        '../../data/deep_learn/teste/',
        target_size=(image_size, image_size),
        batch_size=val_batchsize,
        class_mode='categorical',
        shuffle=True)
# Out:
# Found 1500 images belonging to 2 classes.
# Found 500 images belonging to 2 classes.

# %%
model.compile(loss='categorical_crossentropy',
              #optimizer=optimizers.RMSprop(lr=1e-4),
              optimizer='sgd',
              metrics=['acc'])

# %%
# Train the model
history = model.fit_generator(
      train_generator,
      steps_per_epoch=train_generator.samples/train_generator.batch_size ,
      epochs=20,
      validation_data=validation_generator,
      validation_steps=validation_generator.samples/validation_generator.batch_size,verbose=1)
# Out:
# Epoch 1/20
# 30/30 [==============================] - 63s 2s/step - loss: 1.3686 - acc: 0.8087 - val_loss: 0.2583 - val_acc: 0.9320
# Epoch 2/20
# 30/30 [==============================] - 50s 2s/step - loss: 0.3548 - acc: 0.9053 - val_loss: 0.3821 - val_acc: 0.8980
# Epoch 3/20
# 30/30 [==============================] - 51s 2s/step - loss: 0.2788 - acc: 0.9227 - val_loss: 0.2748 - val_acc: 0.9260
# Epoch 4/20
# 30/30 [==============================] - 51s 2s/step - loss: 0.1542 - acc: 0.9493 - val_loss: 0.2787 - val_acc: 0.9360
# Epoch 5/20
# 30/30 [==============================] - 54s 2s/step - loss: 0.1523 - acc: 0.9480 - val_loss: 0.2752 - val_acc: 0.9260
# Epoch 6/20
# 30/30 [==============================] - 55s 2s/step - loss: 0.1400 - acc: 0.9567 - val_loss: 0.2854 - val_acc: 0.9320
# Epoch 7/20
# 30/30 [==============================] - 51s 2s/step - loss: 0.1465 - acc: 0.9540 - val_loss: 0.2695 - val_acc: 0.9320
# Epoch 8/20
# 30/30 [==============================] - 50s 2s/step - loss: 0.1259 - acc: 0.9560 - val_loss: 0.2308 - val_acc: 0.9440
# Epoch 9/20
# 30/30 [==============================] - 50s 2s/step - loss: 0.1041 - acc: 0.9647 - val_loss: 0.2279 - val_acc: 0.9300
# Epoch 10/20
# 30/30 [==============================] - 51s 2s/step - loss: 0.1294 - acc: 0.9533 - val_loss: 0.2219 - val_acc: 0.9480
# Epoch 11/20
# 30/30 [==============================] - 50s 2s/step - loss: 0.1127 - acc: 0.9600 - val_loss: 0.2318 - val_acc: 0.9460
# Epoch 12/20
# 30/30 [==============================] - 51s 2s/step - loss: 0.0935 - acc: 0.9693 - val_loss: 0.2277 - val_acc: 0.9420
# Epoch 13/20
# 30/30 [==============================] - 50s 2s/step - loss: 0.0769 - acc: 0.9760 - val_loss: 0.2332 - val_acc: 0.9440
# Epoch 14/20
# 30/30 [==============================] - 51s 2s/step - loss: 0.0982 - acc: 0.9673 - val_loss: 0.2340 - val_acc: 0.9420
# Epoch 15/20
# 30/30 [==============================] - 51s 2s/step - loss: 0.0901 - acc: 0.9673 - val_loss: 0.2248 - val_acc: 0.9440
# Epoch 16/20
# 30/30 [==============================] - 50s 2s/step - loss: 0.0877 - acc: 0.9660 - val_loss: 0.2210 - val_acc: 0.9480
# Epoch 17/20
# 30/30 [==============================] - 51s 2s/step - loss: 0.0896 - acc: 0.9667 - val_loss: 0.2131 - val_acc: 0.9480
# Epoch 18/20
# 30/30 [==============================] - 54s 2s/step - loss: 0.0886 - acc: 0.9680 - val_loss: 0.2321 - val_acc: 0.9440
# Epoch 19/20
# 30/30 [==============================] - 51s 2s/step - loss: 0.0667 - acc: 0.9773 - val_loss: 0.2422 - val_acc: 0.9420
# Epoch 20/20
# 30/30 [==============================] - 50s 2s/step - loss: 0.0781 - acc: 0.9753 - val_loss: 0.2334 - val_acc: 0.9440

# %%
 
# Save the model
model.save('estomato_dense_final.h5')

# %%
import matplotlib.pyplot as plt

acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']
 
epochs = range(len(acc))
 
plt.plot(epochs, acc, 'b', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()
 
plt.figure()
 
plt.plot(epochs, loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
 
plt.show()

# %%
# Create a generator for prediction
validation_generator = validation_datagen.flow_from_directory(
        '../../data/deep_learn/teste/',
        target_size=(image_size, image_size),
        batch_size=val_batchsize,
        class_mode='categorical',
        shuffle=False)
# Out:
# Found 500 images belonging to 2 classes.

# %%
 
# Get the filenames from the generator
fnames = validation_generator.filenames
 
# Get the ground truth from generator
ground_truth = validation_generator.classes
 
# Get the label to class mapping from the generator
label2index = validation_generator.class_indices
 
# Getting the mapping from class index to class label
idx2label = dict((v,k) for k,v in label2index.items())
 
# Get the predictions from the model using the generator
predictions = model.predict_generator(validation_generator, steps=validation_generator.samples/validation_generator.batch_size,verbose=1)
predicted_classes = np.argmax(predictions,axis=1)
 
errors = np.where(predicted_classes != ground_truth)[0]
print("No of errors = {}/{}".format(len(errors),validation_generator.samples))
 
# Show the errors
for i in range(len(errors)):
    pred_class = np.argmax(predictions[errors[i]])
    pred_label = idx2label[pred_class]
     
    title = 'Original label:{}, Prediction :{}, confidence : {:.3f}'.format(
        fnames[errors[i]].split('/')[0],
        pred_label,
        predictions[errors[i]][pred_class])
     
    original = load_img('{}/{}'.format('../../data/deep_learn/teste/',fnames[errors[i]]))
    plt.figure(figsize=[7,7])
    plt.axis('off')
    plt.title(title)
    plt.imshow(original)
    plt.show()
# Out:
# 50/50 [==============================] - 16s 326ms/step
# No of errors = 28/500

# %%
early_stop = EarlyStopping(monitor='val_loss', min_delta=0, patience=3, verbose=1, mode='auto')


# Create the model
model = models.Sequential()
 
# Add the vgg convolutional base model
model.add(resnet_conv)
 
# Add new layers
model.add(layers.Flatten())
model.add(layers.Dense(1024, activation='relu'))
model.add(layers.Dropout(0.75))
model.add(layers.Dense(2, activation='softmax'))
 
# Show a summary of the model. Check the number of trainable parameters
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# densenet121 (Model)          (None, 7, 7, 1024)        7037504
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 50176)             0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1024)              51381248
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 2)                 2050
# =================================================================
# Total params: 58,420,802
# Trainable params: 51,422,210
# Non-trainable params: 6,998,592
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy',
              #optimizer=optimizers.RMSprop(lr=1e-4),
              optimizer='sgd',
              metrics=['acc'])

# %%
# Train the model
history = model.fit_generator(
      train_generator,
      steps_per_epoch=train_generator.samples/train_generator.batch_size ,
      epochs=10,
      validation_data=validation_generator,
      validation_steps=validation_generator.samples/validation_generator.batch_size,verbose=1)
# Out:
# Epoch 1/10
# 30/30 [==============================] - 59s 2s/step - loss: 1.3472 - acc: 0.8147 - val_loss: 0.3977 - val_acc: 0.9340
# Epoch 2/10
# 30/30 [==============================] - 50s 2s/step - loss: 0.3441 - acc: 0.9293 - val_loss: 0.3354 - val_acc: 0.9420
# Epoch 3/10
# 30/30 [==============================] - 50s 2s/step - loss: 0.3326 - acc: 0.9247 - val_loss: 0.2948 - val_acc: 0.9420
# Epoch 4/10
# 30/30 [==============================] - 50s 2s/step - loss: 0.2482 - acc: 0.9420 - val_loss: 0.3049 - val_acc: 0.9460
# Epoch 5/10
# 30/30 [==============================] - 50s 2s/step - loss: 0.2095 - acc: 0.9413 - val_loss: 0.3129 - val_acc: 0.9380
# Epoch 6/10
# 30/30 [==============================] - 51s 2s/step - loss: 0.1737 - acc: 0.9540 - val_loss: 0.2709 - val_acc: 0.9360
# Epoch 7/10
# 30/30 [==============================] - 51s 2s/step - loss: 0.1111 - acc: 0.9587 - val_loss: 0.2683 - val_acc: 0.9340
# Epoch 8/10
# 30/30 [==============================] - 51s 2s/step - loss: 0.1606 - acc: 0.9553 - val_loss: 0.2491 - val_acc: 0.9360
# Epoch 9/10
# 30/30 [==============================] - 51s 2s/step - loss: 0.1283 - acc: 0.9600 - val_loss: 0.2416 - val_acc: 0.9400
# Epoch 10/10
# 30/30 [==============================] - 51s 2s/step - loss: 0.1248 - acc: 0.9607 - val_loss: 0.2330 - val_acc: 0.9420

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# densenet121 (Model)          (None, 7, 7, 1024)        7037504
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 50176)             0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1024)              51381248
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 2)                 2050
# =================================================================
# Total params: 58,420,802
# Trainable params: 51,422,210
# Non-trainable params: 6,998,592
# _________________________________________________________________

# %%
model.pop()
model.pop()
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# densenet121 (Model)          (None, 7, 7, 1024)        7037504
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 50176)             0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1024)              51381248
# =================================================================
# Total params: 58,420,802
# Trainable params: 51,422,210
# Non-trainable params: 6,998,592
# _________________________________________________________________
# /usr/local/lib/python2.7/dist-packages/keras/engine/training.py:478: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'

# %%
model.save('estomato_dense_final.h5')
