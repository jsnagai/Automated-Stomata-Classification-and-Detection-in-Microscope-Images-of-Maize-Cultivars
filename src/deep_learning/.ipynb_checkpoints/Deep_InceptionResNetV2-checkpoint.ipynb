# %%
from keras.applications import InceptionResNetV2
import os
import numpy as np
import cv2
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.applications.imagenet_utils import decode_predictions
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Model Download

# %%
import tensorflow as tf
from keras import backend as K

config = tf.ConfigProto()
config.gpu_options.allow_growth=True
sess = tf.Session(config=config)
K.set_session(sess)

# %%
image_size = 224
resnet_conv = InceptionResNetV2(weights='imagenet', include_top=False, input_shape=(image_size, image_size,3))

# %%
for layer in resnet_conv.layers[:-4]:     
    layer.trainable = False
for layer in resnet_conv.layers:
    print(layer, layer.trainable)
# Out:
# (<keras.engine.input_layer.InputLayer object at 0x7f034dffba10>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f034dffbdd0>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f034dffbc90>, False)
# (<keras.layers.core.Activation object at 0x7f03e01bf6d0>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f034dfe5fd0>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f034e0140d0>, False)
# (<keras.layers.core.Activation object at 0x7f034dea0410>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f034de36650>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f034c3aaf50>, False)
# (<keras.layers.core.Activation object at 0x7f034c330ad0>, False)
# (<keras.layers.pooling.MaxPooling2D object at 0x7f034c307d10>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f034c2ca390>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f034c321e50>, False)
# (<keras.layers.core.Activation object at 0x7f034c0f76d0>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f034c0ece10>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f034c0ecd90>, False)
# (<keras.layers.core.Activation object at 0x7f034c033bd0>, False)
# (<keras.layers.pooling.MaxPooling2D object at 0x7f034c003e10>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f0332389c50>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f033234c250>, False)
# (<keras.layers.core.Activation object at 0x7f033237a910>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f0332763fd0>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f03323a4d90>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f0332763f10>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f03322dd410>, False)
# (<keras.layers.core.Activation object at 0x7f03326a9210>, False)
# (<keras.layers.core.Activation object at 0x7f03322badd0>, False)
# (<keras.layers.pooling.AveragePooling2D object at 0x7f0332116c90>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f034c042350>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f0332678f50>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f03321ca510>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f0332174190>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f034c025f50>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f0332661e10>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f033222de10>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f0332169dd0>, False)
# (<keras.layers.core.Activation object at 0x7f033276f610>, False)
# (<keras.layers.core.Activation object at 0x7f03323b1a10>, False)
# (<keras.layers.core.Activation object at 0x7f03321f5ed0>, False)
# (<keras.layers.core.Activation object at 0x7f033208da90>, False)
# (<keras.layers.merge.Concatenate object at 0x7f03320484d0>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f0331e5da50>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f0331e76f50>, False)
# (<keras.layers.core.Activation object at 0x7f0331dcdc50>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f0331fff750>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f0331d54610>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f0331fff910>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f0331d46f90>, False)
# (<keras.layers.core.Activation object at 0x7f0331f4ebd0>, False)
# (<keras.layers.core.Activation object at 0x7f0331d139d0>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f03320a7f10>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f0331ecf890>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f0331ce0ed0>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f03320a7650>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f0331ec1fd0>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f0331cfaed0>, False)
# (<keras.layers.core.Activation object at 0x7f0332002610>, False)
# (<keras.layers.core.Activation object at 0x7f0331e8ea50>, False)
# (<keras.layers.core.Activation object at 0x7f0331bc9b10>, False)
# (<keras.layers.merge.Concatenate object at 0x7f0331c1fdd0>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f0331be2250>, False)
# (<keras.layers.core.Lambda object at 0x7f0331b51c50>, False)
# (<keras.layers.core.Activation object at 0x7f0331b90c10>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f0331959190>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f03319bed50>, False)
# (<keras.layers.core.Activation object at 0x7f03318ff790>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f0331ad1410>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f0331906990>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f0331b32f10>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f03318f0510>, False)
# (<keras.layers.core.Activation object at 0x7f0331a91390>, False)
# (<keras.layers.core.Activation object at 0x7f03317c6c50>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f0331b90b50>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f0331a82a90>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f0331812f10>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f0331b90c90>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f0331a67590>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f03317de110>, False)
# (<keras.layers.core.Activation object at 0x7f0331b24e50>, False)
# (<keras.layers.core.Activation object at 0x7f03319c8c90>, False)
# (<keras.layers.core.Activation object at 0x7f033178ddd0>, False)
# (<keras.layers.merge.Concatenate object at 0x7f0331701c90>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f03316cbe90>, False)
# (<keras.layers.core.Lambda object at 0x7f033170ff10>, False)
# (<keras.layers.core.Activation object at 0x7f03316a9f10>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f0331514690>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f03314a7d50>, False)
# (<keras.layers.core.Activation object at 0x7f0331453b90>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f0331620d90>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f03313dc4d0>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f033163bf90>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f0331438e10>, False)
# (<keras.layers.core.Activation object at 0x7f03315cbbd0>, False)
# (<keras.layers.core.Activation object at 0x7f033138af10>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f0331656d90>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f03315562d0>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f033132acd0>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f03316da2d0>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f03315b8e90>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f033130c290>, False)
# (<keras.layers.core.Activation object at 0x7f0331601390>, False)
# (<keras.layers.core.Activation object at 0x7f033148be50>, False)
# (<keras.layers.core.Activation object at 0x7f03312d5b10>, False)
# (<keras.layers.merge.Concatenate object at 0x7f03312a3f10>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f03312bffd0>, False)
# (<keras.layers.core.Lambda object at 0x7f0331265490>, False)
# (<keras.layers.core.Activation object at 0x7f03311dbed0>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f033101cbd0>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f0330fdf410>, False)
# (<keras.layers.core.Activation object at 0x7f0330f022d0>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f03311590d0>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f0330f53d10>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f03311bf9d0>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f0330f26dd0>, False)
# (<keras.layers.core.Activation object at 0x7f0331080350>, False)
# (<keras.layers.core.Activation object at 0x7f0330ed4c10>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f0331218890>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f03310cdd90>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f0330e9eb50>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f03312186d0>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f0331040d90>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f0330eb7f50>, False)
# (<keras.layers.core.Activation object at 0x7f03311aba50>, False)
# (<keras.layers.core.Activation object at 0x7f0330fc5910>, False)
# (<keras.layers.core.Activation object at 0x7f0330e11dd0>, False)
# (<keras.layers.merge.Concatenate object at 0x7f0330da9490>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f0330d8ddd0>, False)
# (<keras.layers.core.Lambda object at 0x7f0330d8df10>, False)
# (<keras.layers.core.Activation object at 0x7f0330d66610>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f0330b1c650>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f0330b01f10>, False)
# (<keras.layers.core.Activation object at 0x7f0330ada390>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f0330cf8050>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f0330accc10>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f0330cf8f10>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f0330a63150>, False)
# (<keras.layers.core.Activation object at 0x7f0330c543d0>, False)
# (<keras.layers.core.Activation object at 0x7f0330a11b10>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f0330d66350>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f0330c46c50>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f03309a5350>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f0330d663d0>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f0330bdb110>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f0330989f90>, False)
# (<keras.layers.core.Activation object at 0x7f0330c96450>, False)
# (<keras.layers.core.Activation object at 0x7f0330b88dd0>, False)
# (<keras.layers.core.Activation object at 0x7f03308d3390>, False)
# (<keras.layers.merge.Concatenate object at 0x7f03308f5dd0>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f0330891fd0>, False)
# (<keras.layers.core.Lambda object at 0x7f0330960710>, False)
# (<keras.layers.core.Activation object at 0x7f033086bb10>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f0330607e50>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f03306d8910>, False)
# (<keras.layers.core.Activation object at 0x7f033061cad0>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f0330834fd0>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f03305a0490>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f0330834550>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f03305fef90>, False)
# (<keras.layers.core.Activation object at 0x7f0330792b90>, False)
# (<keras.layers.core.Activation object at 0x7f03304cc4d0>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f0330826f50>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f033071c7d0>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f0330487e10>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f03308a1590>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f0330779f50>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f033055b850>, False)
# (<keras.layers.core.Activation object at 0x7f03307c45d0>, False)
# (<keras.layers.core.Activation object at 0x7f0330649550>, False)
# (<keras.layers.core.Activation object at 0x7f0330412990>, False)
# (<keras.layers.merge.Concatenate object at 0x7f0330469c50>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f033042d0d0>, False)
# (<keras.layers.core.Lambda object at 0x7f0330405d90>, False)
# (<keras.layers.core.Activation object at 0x7f033039ad90>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f03301d6e10>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f03301a6090>, False)
# (<keras.layers.core.Activation object at 0x7f0330153850>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f0330322090>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f0330137950>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f03302df110>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f0330137f10>, False)
# (<keras.layers.core.Activation object at 0x7f03302ce890>, False)
# (<keras.layers.core.Activation object at 0x7f0330011ad0>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f03303d8ad0>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f0330303890>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f0330068d90>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f03303d8b10>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f03302b6410>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f033002a850>, False)
# (<keras.layers.core.Activation object at 0x7f0330372cd0>, False)
# (<keras.layers.core.Activation object at 0x7f033018db50>, False)
# (<keras.layers.core.Activation object at 0x7f02f3fd5e10>, False)
# (<keras.layers.merge.Concatenate object at 0x7f02f3f6c450>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02f3f51fd0>, False)
# (<keras.layers.core.Lambda object at 0x7f02f3f51c50>, False)
# (<keras.layers.core.Activation object at 0x7f02f3eb1e90>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02f3ce0610>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02f3cd4f90>, False)
# (<keras.layers.core.Activation object at 0x7f02f3ca09d0>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02f3e6cc50>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02f3cc1cd0>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02f3e0eb50>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02f3c2c0d0>, False)
# (<keras.layers.core.Activation object at 0x7f02f3e1ba90>, False)
# (<keras.layers.core.Activation object at 0x7f02f3bd8d50>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02f3f27190>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02f3ebe190>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02f3b68590>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02f3f27550>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02f3da3410>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02f3b57ed0>, False)
# (<keras.layers.core.Activation object at 0x7f02f3e4f110>, False)
# (<keras.layers.core.Activation object at 0x7f02f3d4fe10>, False)
# (<keras.layers.core.Activation object at 0x7f02f3a9b5d0>, False)
# (<keras.layers.merge.Concatenate object at 0x7f02f3a90fd0>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02f3abb390>, False)
# (<keras.layers.core.Lambda object at 0x7f02f3b27550>, False)
# (<keras.layers.core.Activation object at 0x7f02f3a30d50>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02f3863ed0>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02f387bf10>, False)
# (<keras.layers.core.Activation object at 0x7f02f37d3c10>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02f39f9ed0>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02f3768c50>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02f39f9790>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02f374a250>, False)
# (<keras.layers.core.Activation object at 0x7f02f3958c90>, False)
# (<keras.layers.core.Activation object at 0x7f02f3714a90>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02f3a677d0>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02f38f0cd0>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02f36e0fd0>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02f3a67750>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02f38ce2d0>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02f369f110>, False)
# (<keras.layers.core.Activation object at 0x7f02f398d810>, False)
# (<keras.layers.core.Activation object at 0x7f02f389bb10>, False)
# (<keras.layers.core.Activation object at 0x7f02f35cfbd0>, False)
# (<keras.layers.merge.Concatenate object at 0x7f02f3615e90>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02f35e7310>, False)
# (<keras.layers.core.Lambda object at 0x7f02f363efd0>, False)
# (<keras.layers.core.Activation object at 0x7f02f3595c10>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02f335a250>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02f33bfe10>, False)
# (<keras.layers.core.Activation object at 0x7f02f331a3d0>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02f34d94d0>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02f330bad0>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02f353afd0>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02f32f05d0>, False)
# (<keras.layers.core.Activation object at 0x7f02f349a450>, False)
# (<keras.layers.core.Activation object at 0x7f02f324ed50>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02f35a60d0>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02f348bb50>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02f31e11d0>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02f35a6250>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02f346c650>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02f31c7d90>, False)
# (<keras.layers.core.Activation object at 0x7f02f352cf10>, False)
# (<keras.layers.core.Activation object at 0x7f02f33c9f50>, False)
# (<keras.layers.core.Activation object at 0x7f02f3192e90>, False)
# (<keras.layers.merge.Concatenate object at 0x7f02f3105d50>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02f30d0f50>, False)
# (<keras.layers.core.Lambda object at 0x7f02f3114fd0>, False)
# (<keras.layers.core.Activation object at 0x7f02f30aaa50>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02f303ed90>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02f3072450>, False)
# (<keras.layers.core.Activation object at 0x7f02f2fcecd0>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02f2f533d0>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02f2fb4f10>, False)
# (<keras.layers.core.Activation object at 0x7f02f2e82410>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f03320a7590>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02f2ebcd50>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02f305ae50>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02f2f12790>, False)
# (<keras.layers.core.Activation object at 0x7f02f3001490>, False)
# (<keras.layers.core.Activation object at 0x7f02f2dc28d0>, False)
# (<keras.layers.pooling.MaxPooling2D object at 0x7f02f2e19b50>, False)
# (<keras.layers.merge.Concatenate object at 0x7f02f2e4e190>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02f2d24590>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02f2d0cfd0>, False)
# (<keras.layers.core.Activation object at 0x7f02f2ce2310>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02f2cd0b90>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02f2c68150>, False)
# (<keras.layers.core.Activation object at 0x7f02f2c16fd0>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02f2d8aa50>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02f2ba6310>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02f2d8a650>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02f2b87e90>, False)
# (<keras.layers.core.Activation object at 0x7f02f2d73f50>, False)
# (<keras.layers.core.Activation object at 0x7f02f2ad7250>, False)
# (<keras.layers.merge.Concatenate object at 0x7f02f2b67710>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02f2af5d90>, False)
# (<keras.layers.core.Lambda object at 0x7f02f2a94f90>, False)
# (<keras.layers.core.Activation object at 0x7f02f2a72ad0>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02f29e1210>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02f294f750>, False)
# (<keras.layers.core.Activation object at 0x7f02f298d810>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02f2977dd0>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02f2977fd0>, False)
# (<keras.layers.core.Activation object at 0x7f02f284ca50>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02f2aa5550>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02f28a2d50>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02f2aa5790>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02f2866090>, False)
# (<keras.layers.core.Activation object at 0x7f02f2a2ec50>, False)
# (<keras.layers.core.Activation object at 0x7f02f2811c50>, False)
# (<keras.layers.merge.Concatenate object at 0x7f02f27a56d0>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02f278af90>, False)
# (<keras.layers.core.Lambda object at 0x7f02f278ac50>, False)
# (<keras.layers.core.Activation object at 0x7f02f2761850>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02f26eee90>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02f26ee750>, False)
# (<keras.layers.core.Activation object at 0x7f02f264bc50>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02f23e6c90>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02f23c6290>, False)
# (<keras.layers.core.Activation object at 0x7f02f2392ad0>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02f2761590>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02f2361fd0>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02f27611d0>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02f237bfd0>, False)
# (<keras.layers.core.Activation object at 0x7f02f26817d0>, False)
# (<keras.layers.core.Activation object at 0x7f02f2249b90>, False)
# (<keras.layers.merge.Concatenate object at 0x7f02f2294e90>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02f2262350>, False)
# (<keras.layers.core.Lambda object at 0x7f02f22b7f90>, False)
# (<keras.layers.core.Activation object at 0x7f02f2211c50>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02f2178d50>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02f21aa310>, False)
# (<keras.layers.core.Activation object at 0x7f02f2108c90>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02f2092390>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02f20f5fd0>, False)
# (<keras.layers.core.Activation object at 0x7f02f1fc1e10>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02f2191e50>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02f1ffed10>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02f2222110>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02f2052750>, False)
# (<keras.layers.core.Activation object at 0x7f02f21ba450>, False)
# (<keras.layers.core.Activation object at 0x7f02f1f7f890>, False)
# (<keras.layers.merge.Concatenate object at 0x7f02f1f5bb10>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02f1f74f50>, False)
# (<keras.layers.core.Lambda object at 0x7f02f1f1e650>, False)
# (<keras.layers.core.Activation object at 0x7f02f1e91fd0>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02f1e6aad0>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02f1e08750>, False)
# (<keras.layers.core.Activation object at 0x7f02f1dc54d0>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02f1e37d50>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02f1d51090>, False)
# (<keras.layers.core.Activation object at 0x7f02f1d01b50>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02f1ec9d50>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02f1c90750>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02f1ec9a10>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02f1cf3f90>, False)
# (<keras.layers.core.Activation object at 0x7f02f1e6a0d0>, False)
# (<keras.layers.core.Activation object at 0x7f02f1c3e510>, False)
# (<keras.layers.merge.Concatenate object at 0x7f02f1bfde50>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02f1c2fd90>, False)
# (<keras.layers.core.Lambda object at 0x7f02f1c4c8d0>, False)
# (<keras.layers.core.Activation object at 0x7f02f1b59c50>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02f1ac83d0>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02f1b2aed0>, False)
# (<keras.layers.core.Activation object at 0x7f02f1a6c7d0>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02f1af59d0>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02f1a5a550>, False)
# (<keras.layers.core.Activation object at 0x7f02f1a3ec50>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02f1b8e710>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02f194d150>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02f1b8e690>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02f19b3c90>, False)
# (<keras.layers.core.Activation object at 0x7f02f1b19e10>, False)
# (<keras.layers.core.Activation object at 0x7f02f197ce10>, False)
# (<keras.layers.merge.Concatenate object at 0x7f02f18eda10>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02f18fdf90>, False)
# (<keras.layers.core.Lambda object at 0x7f02f18fd090>, False)
# (<keras.layers.core.Activation object at 0x7f02f184b910>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02f1741f90>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02f17d0710>, False)
# (<keras.layers.core.Activation object at 0x7f02f17b2cd0>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02f177ab10>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02f1731fd0>, False)
# (<keras.layers.core.Activation object at 0x7f02f166dd50>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02f184b550>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02f1660dd0>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02f184b150>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02f16fd910>, False)
# (<keras.layers.core.Activation object at 0x7f02f17e6850>, False)
# (<keras.layers.core.Activation object at 0x7f02f15ae8d0>, False)
# (<keras.layers.merge.Concatenate object at 0x7f02f1586990>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02f1509f90>, False)
# (<keras.layers.core.Lambda object at 0x7f02f15a3f90>, False)
# (<keras.layers.core.Activation object at 0x7f02f153bd10>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02f1498050>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02f1498f10>, False)
# (<keras.layers.core.Activation object at 0x7f02f13e1910>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02f1466f10>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02f13befd0>, False)
# (<keras.layers.core.Activation object at 0x7f02f13afd90>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02f1579890>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02f1290690>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02f15794d0>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02f12ac810>, False)
# (<keras.layers.core.Activation object at 0x7f02f1429b10>, False)
# (<keras.layers.core.Activation object at 0x7f02f12ef590>, False)
# (<keras.layers.merge.Concatenate object at 0x7f02f11efb90>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02f1262f90>, False)
# (<keras.layers.core.Lambda object at 0x7f02f1262f10>, False)
# (<keras.layers.core.Activation object at 0x7f02f122ed50>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02f114cfd0>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02f114c690>, False)
# (<keras.layers.core.Activation object at 0x7f02f1129ad0>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02f1023bd0>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02f1095c50>, False)
# (<keras.layers.core.Activation object at 0x7f02f0fe3410>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02f123e410>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02f10737d0>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02f123e7d0>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02f0fd7f10>, False)
# (<keras.layers.core.Activation object at 0x7f02f115d710>, False)
# (<keras.layers.core.Activation object at 0x7f02f0fb4810>, False)
# (<keras.layers.merge.Concatenate object at 0x7f02f0f75850>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02f0f36510>, False)
# (<keras.layers.core.Lambda object at 0x7f02f0f0ce50>, False)
# (<keras.layers.core.Activation object at 0x7f02f0eacbd0>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02f0d939d0>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02f0e03dd0>, False)
# (<keras.layers.core.Activation object at 0x7f02f0d477d0>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02f0dd1e10>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02f0d67550>, False)
# (<keras.layers.core.Activation object at 0x7f02f0c8ead0>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02f0ee6bd0>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02f0cd8c10>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02f0ee6390>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02f0c80ed0>, False)
# (<keras.layers.core.Activation object at 0x7f02f0e73f50>, False)
# (<keras.layers.core.Activation object at 0x7f02f0c52650>, False)
# (<keras.layers.merge.Concatenate object at 0x7f02f0b57a50>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02f0bcdf10>, False)
# (<keras.layers.core.Lambda object at 0x7f02f0bcdb90>, False)
# (<keras.layers.core.Activation object at 0x7f02f0b98f10>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02f0b32ed0>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02f0b32090>, False)
# (<keras.layers.core.Activation object at 0x7f02f0a94a50>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02f098ab10>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02f0a7af50>, False)
# (<keras.layers.core.Activation object at 0x7f02f094d250>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02f0b24250>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02f09d8750>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02f0ba7290>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02f0942fd0>, False)
# (<keras.layers.core.Activation object at 0x7f02f0ac5610>, False)
# (<keras.layers.core.Activation object at 0x7f02f091a750>, False)
# (<keras.layers.merge.Concatenate object at 0x7f02f08e9790>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02f0880f50>, False)
# (<keras.layers.core.Lambda object at 0x7f02f084afd0>, False)
# (<keras.layers.core.Activation object at 0x7f02f0826b10>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02f0705990>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02f07f9f90>, False)
# (<keras.layers.core.Activation object at 0x7f02f073c790>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02f0749dd0>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02f06dc4d0>, False)
# (<keras.layers.core.Activation object at 0x7f02f0603a90>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02f085bad0>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02f064fbd0>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02f085b290>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02f0674e90>, False)
# (<keras.layers.core.Activation object at 0x7f02f07e6e10>, False)
# (<keras.layers.core.Activation object at 0x7f02f05ca5d0>, False)
# (<keras.layers.merge.Concatenate object at 0x7f02f04c9a10>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02f05bced0>, False)
# (<keras.layers.core.Lambda object at 0x7f02f05bcb50>, False)
# (<keras.layers.core.Activation object at 0x7f02f050cf10>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02f04a9ed0>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02f04a9090>, False)
# (<keras.layers.core.Activation object at 0x7f02f0406a10>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02f0300ad0>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02f03f0f50>, False)
# (<keras.layers.core.Activation object at 0x7f02f02c0210>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02f0490fd0>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02f034e710>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02f051a290>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02f0241e50>, False)
# (<keras.layers.core.Activation object at 0x7f02f04b8610>, False)
# (<keras.layers.core.Activation object at 0x7f02f0206690>, False)
# (<keras.layers.merge.Concatenate object at 0x7f02f027af10>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02f01c1fd0>, False)
# (<keras.layers.core.Lambda object at 0x7f02f028c110>, False)
# (<keras.layers.core.Activation object at 0x7f02f019bad0>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02f00fa950>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02f016cf90>, False)
# (<keras.layers.core.Activation object at 0x7f02f00ae750>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02f013cd90>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02f00a2f10>, False)
# (<keras.layers.core.Activation object at 0x7f02efff6a50>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02f01d2ad0>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02effd0b90>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02f01d2290>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02effe7e50>, False)
# (<keras.layers.core.Activation object at 0x7f02f015de10>, False)
# (<keras.layers.core.Activation object at 0x7f02eff405d0>, False)
# (<keras.layers.merge.Concatenate object at 0x7f02efe419d0>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02eff38e90>, False)
# (<keras.layers.core.Lambda object at 0x7f02eff38b10>, False)
# (<keras.layers.core.Activation object at 0x7f02efe82ed0>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02efe21fd0>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02efe210d0>, False)
# (<keras.layers.core.Activation object at 0x7f02efdfd9d0>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02efcf5a90>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02efd62f10>, False)
# (<keras.layers.core.Activation object at 0x7f02efd31a50>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02efe05f10>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02efc34e10>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02efe92250>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02efcb92d0>, False)
# (<keras.layers.core.Activation object at 0x7f02efe315d0>, False)
# (<keras.layers.core.Activation object at 0x7f02efbf8650>, False)
# (<keras.layers.merge.Concatenate object at 0x7f02efbeded0>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02efbb3f90>, False)
# (<keras.layers.core.Lambda object at 0x7f02efc04090>, False)
# (<keras.layers.core.Activation object at 0x7f02efb0ea90>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02efa70910>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02efae0c90>, False)
# (<keras.layers.core.Activation object at 0x7f02efa22710>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02efaaed50>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02efa14ed0>, False)
# (<keras.layers.core.Activation object at 0x7f02ef96ea10>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02efb45a90>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02ef941b50>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02efb45250>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02ef95ee10>, False)
# (<keras.layers.core.Activation object at 0x7f02efad0dd0>, False)
# (<keras.layers.core.Activation object at 0x7f02ef936590>, False)
# (<keras.layers.merge.Concatenate object at 0x7f02ef837990>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02ef8aed10>, False)
# (<keras.layers.core.Lambda object at 0x7f02ef8aead0>, False)
# (<keras.layers.core.Activation object at 0x7f02ef879e90>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02ef793f90>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02ef793090>, False)
# (<keras.layers.core.Activation object at 0x7f02ef773990>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02ef66aa50>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02ef6dbfd0>, False)
# (<keras.layers.core.Activation object at 0x7f02ef6aaa10>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02ef7f8ed0>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02ef5a9dd0>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02ef808210>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02ef62d290>, False)
# (<keras.layers.core.Activation object at 0x7f02ef7a5590>, False)
# (<keras.layers.core.Activation object at 0x7f02ef56e610>, False)
# (<keras.layers.merge.Concatenate object at 0x7f02ef55fe90>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02ef528fd0>, False)
# (<keras.layers.core.Lambda object at 0x7f02ef5f9050>, False)
# (<keras.layers.core.Activation object at 0x7f02ef489a50>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02ef3e78d0>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02ef456c50>, False)
# (<keras.layers.core.Activation object at 0x7f02ef39b6d0>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02ef423d10>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02ef38fe90>, False)
# (<keras.layers.core.Activation object at 0x7f02ef2e29d0>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02ef53aa50>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02ef338b10>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02ef53a210>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02ef2d2dd0>, False)
# (<keras.layers.core.Activation object at 0x7f02ef448d90>, False)
# (<keras.layers.core.Activation object at 0x7f02ef2ac550>, False)
# (<keras.layers.merge.Concatenate object at 0x7f02ef1ac950>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02ef221cd0>, False)
# (<keras.layers.core.Lambda object at 0x7f02ef221a90>, False)
# (<keras.layers.core.Activation object at 0x7f02ef1efe50>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02ef107f50>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02ef107190>, False)
# (<keras.layers.core.Activation object at 0x7f02ef0e5950>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02eefdfa10>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02ef053f90>, False)
# (<keras.layers.core.Activation object at 0x7f02ef0239d0>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02ef170e90>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02eef96ad0>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02ef1ff1d0>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02eefa2250>, False)
# (<keras.layers.core.Activation object at 0x7f02ef119550>, False)
# (<keras.layers.core.Activation object at 0x7f02eeee4dd0>, False)
# (<keras.layers.merge.Concatenate object at 0x7f02eeed6e50>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02eee9df90>, False)
# (<keras.layers.core.Lambda object at 0x7f02eef70990>, False)
# (<keras.layers.core.Activation object at 0x7f02eee7ba10>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02eed59890>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02eedccc10>, False)
# (<keras.layers.core.Activation object at 0x7f02eed10690>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02eed98cd0>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02eed03e50>, False)
# (<keras.layers.core.Activation object at 0x7f02eec59a10>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02eeeafa10>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02eecb0ad0>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02eeeaf1d0>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02eec4bd90>, False)
# (<keras.layers.core.Activation object at 0x7f02eee3bd50>, False)
# (<keras.layers.core.Activation object at 0x7f02eec21510>, False)
# (<keras.layers.merge.Concatenate object at 0x7f02eeb26910>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02eeb99d90>, False)
# (<keras.layers.core.Lambda object at 0x7f02eeb99f50>, False)
# (<keras.layers.core.Activation object at 0x7f02eeb61e10>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02ee840dd0>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02ee8df950>, False)
# (<keras.layers.core.Activation object at 0x7f02ee81c950>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02f2e36f90>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02eea29ad0>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02ee704a10>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02eeae9e90>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02ee9eb5d0>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02ee7f8f90>, False)
# (<keras.layers.core.Activation object at 0x7f02eea914d0>, False)
# (<keras.layers.core.Activation object at 0x7f02ee99cc10>, False)
# (<keras.layers.core.Activation object at 0x7f02ee7489d0>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02eea4dd90>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02ee962b10>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02ee644d90>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02eea82490>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02ee913fd0>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02ee6c9250>, False)
# (<keras.layers.core.Activation object at 0x7f02eea5ec50>, False)
# (<keras.layers.core.Activation object at 0x7f02ee84cd50>, False)
# (<keras.layers.core.Activation object at 0x7f02ee6045d0>, False)
# (<keras.layers.pooling.MaxPooling2D object at 0x7f02ee674e50>, False)
# (<keras.layers.merge.Concatenate object at 0x7f02ee695650>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02ee54ed10>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02ee5b6d10>, False)
# (<keras.layers.core.Activation object at 0x7f02ee521890>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02ee416990>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02ee48ee10>, False)
# (<keras.layers.core.Activation object at 0x7f02ee459910>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02ee5cea10>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02ee3cca50>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02ee5ce590>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02ee3daf90>, False)
# (<keras.layers.core.Activation object at 0x7f02ee5544d0>, False)
# (<keras.layers.core.Activation object at 0x7f02ee31bd50>, False)
# (<keras.layers.merge.Concatenate object at 0x7f02ee30edd0>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02ee2d6f10>, False)
# (<keras.layers.core.Lambda object at 0x7f02ee3a9910>, False)
# (<keras.layers.core.Activation object at 0x7f02ee2b5990>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02ee207dd0>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02ee2078d0>, False)
# (<keras.layers.core.Activation object at 0x7f02ee146490>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02ee1d1810>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02ee1b8f50>, False)
# (<keras.layers.core.Activation object at 0x7f02ee08f910>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02ee2e8990>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02ee0e49d0>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02ee2e8150>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02ee069fd0>, False)
# (<keras.layers.core.Activation object at 0x7f02ee274d10>, False)
# (<keras.layers.core.Activation object at 0x7f02ee059d90>, False)
# (<keras.layers.merge.Concatenate object at 0x7f02edfba690>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02edf5a810>, False)
# (<keras.layers.core.Lambda object at 0x7f02edfd0b90>, False)
# (<keras.layers.core.Activation object at 0x7f02edf99cd0>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02edf33d90>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02edf33210>, False)
# (<keras.layers.core.Activation object at 0x7f02ede91790>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02edd90850>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02ede7ccd0>, False)
# (<keras.layers.core.Activation object at 0x7f02eddce5d0>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02edf1bfd0>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02edccbbd0>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02edf99d90>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02edd42f50>, False)
# (<keras.layers.core.Activation object at 0x7f02edec4390>, False)
# (<keras.layers.core.Activation object at 0x7f02edc93410>, False)
# (<keras.layers.merge.Concatenate object at 0x7f02edd1e7d0>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02edc86f10>, False)
# (<keras.layers.core.Lambda object at 0x7f02edd0fed0>, False)
# (<keras.layers.core.Activation object at 0x7f02edc2a850>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02edbfcc90>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02edbfc790>, False)
# (<keras.layers.core.Activation object at 0x7f02edb3b350>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02edb47e10>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02edb2fe90>, False)
# (<keras.layers.core.Activation object at 0x7f02eda8c850>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02edc5c850>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02eda5b890>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02edc5c150>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02eda1d510>, False)
# (<keras.layers.core.Activation object at 0x7f02edbe8bd0>, False)
# (<keras.layers.core.Activation object at 0x7f02ed947ad0>, False)
# (<keras.layers.merge.Concatenate object at 0x7f02ed995c10>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02ed9b7ed0>, False)
# (<keras.layers.core.Lambda object at 0x7f02ed8cee10>, False)
# (<keras.layers.core.Activation object at 0x7f02ed90de90>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02ed83dd90>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02ed8afb10>, False)
# (<keras.layers.core.Activation object at 0x7f02ed80d650>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02ed87fb10>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02ed7da950>, False)
# (<keras.layers.core.Activation object at 0x7f02ed7bc6d0>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02ed893e90>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02ed641a90>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02ed90d890>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02ed738f50>, False)
# (<keras.layers.core.Activation object at 0x7f02ed8be150>, False)
# (<keras.layers.core.Activation object at 0x7f02ed684a10>, False)
# (<keras.layers.merge.Concatenate object at 0x7f02ed582e10>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02ed67ab50>, False)
# (<keras.layers.core.Lambda object at 0x7f02ed6072d0>, False)
# (<keras.layers.core.Activation object at 0x7f02ed5d5110>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02ed4ccf90>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02ed572e10>, False)
# (<keras.layers.core.Activation object at 0x7f02ed4b2210>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02ed4a5b90>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02ed436e50>, False)
# (<keras.layers.core.Activation object at 0x7f02ed3fb690>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02ed5d5690>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02ed3eff10>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02ed5d5710>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02ed405050>, False)
# (<keras.layers.core.Activation object at 0x7f02ed55ea90>, False)
# (<keras.layers.core.Activation object at 0x7f02ed33ca10>, False)
# (<keras.layers.merge.Concatenate object at 0x7f02ed312ad0>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02ed32ed90>, False)
# (<keras.layers.core.Lambda object at 0x7f02ed249cd0>, False)
# (<keras.layers.core.Activation object at 0x7f02ed283610>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02ecfafc50>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02ed224110>, False)
# (<keras.layers.core.Activation object at 0x7f02ecf649d0>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02ecff0f90>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02ecf4df90>, False)
# (<keras.layers.core.Activation object at 0x7f02ecf36590>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02ed207f90>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02ece3a950>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02ed283dd0>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02eceb1cd0>, False)
# (<keras.layers.core.Activation object at 0x7f02ed234c50>, False)
# (<keras.layers.core.Activation object at 0x7f02ece7d690>, False)
# (<keras.layers.merge.Concatenate object at 0x7f02ecdefa10>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02ecdfef90>, False)
# (<keras.layers.core.Lambda object at 0x7f02ecdfe0d0>, False)
# (<keras.layers.core.Activation object at 0x7f02ecd4a910>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02ecc845d0>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02eccd4750>, False)
# (<keras.layers.core.Activation object at 0x7f02eccb3c10>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02ecc78b10>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02ecc30f90>, False)
# (<keras.layers.core.Activation object at 0x7f02ecb6ed50>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02ecd4a550>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02ecb62dd0>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02ecd4a150>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02ecbfd950>, False)
# (<keras.layers.core.Activation object at 0x7f02ecce7850>, False)
# (<keras.layers.core.Activation object at 0x7f02ecab48d0>, False)
# (<keras.layers.merge.Concatenate object at 0x7f02eca8b990>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02eca0cf90>, False)
# (<keras.layers.core.Lambda object at 0x7f02ecaa7f90>, False)
# (<keras.layers.core.Activation object at 0x7f02eca3bd10>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02ec99a050>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02ec99af10>, False)
# (<keras.layers.core.Activation object at 0x7f02ec8df910>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02ec968f50>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02ec8ff150>, False)
# (<keras.layers.core.Activation object at 0x7f02ec8ace90>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02eca7c890>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02ec792690>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02eca7c4d0>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02ec7b4810>, False)
# (<keras.layers.core.Activation object at 0x7f02ec926b10>, False)
# (<keras.layers.core.Activation object at 0x7f02ec7f4550>, False)
# (<keras.layers.merge.Concatenate object at 0x7f02ec6efb90>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02ec767f90>, False)
# (<keras.layers.core.Lambda object at 0x7f02ec767f10>, False)
# (<keras.layers.core.Activation object at 0x7f02ec731d50>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02ec64bf90>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02ec64b910>, False)
# (<keras.layers.core.Activation object at 0x7f02ec62bad0>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02ec593f90>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02ec593c10>, False)
# (<keras.layers.core.Activation object at 0x7f02ec4e63d0>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02ee63df90>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02ec4d8ed0>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02ec6c0410>, False)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02ec5747d0>, False)
# (<keras.layers.core.Activation object at 0x7f02ec65f6d0>, False)
# (<keras.layers.core.Activation object at 0x7f02ec4b4790>, False)
# (<keras.layers.merge.Concatenate object at 0x7f02ec403810>, False)
# (<keras.layers.convolutional.Conv2D object at 0x7f02ec41efd0>, False)
# (<keras.layers.core.Lambda object at 0x7f02ec3ded10>, True)
# (<keras.layers.convolutional.Conv2D object at 0x7f02ec342b90>, True)
# (<keras.layers.normalization.BatchNormalization object at 0x7f02ec3f6b90>, True)
# (<keras.layers.core.Activation object at 0x7f02ec303f10>, True)

# %% [markdown]
# ## Creating a new Model

# %%
from keras import models
from keras import layers
from keras import optimizers
from keras.callbacks import EarlyStopping

early_stop = EarlyStopping(monitor='val_loss', min_delta=0, patience=3, verbose=1, mode='auto')


# Create the model
model = models.Sequential()
 
# Add the vgg convolutional base model
model.add(resnet_conv)
 
# Add new layers
model.add(layers.Flatten())
model.add(layers.Dense(1024, activation='relu'))
model.add(layers.Dropout(0.75))
model.add(layers.Dense(2, activation='softmax'))
 
# Show a summary of the model. Check the number of trainable parameters
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inception_resnet_v2 (Model)  (None, 5, 5, 1536)        54336736
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 38400)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              39322624
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 2050
# =================================================================
# Total params: 93,661,410
# Trainable params: 42,521,090
# Non-trainable params: 51,140,320
# _________________________________________________________________

# %% [markdown]
# ## Setup data generators

# %%
from keras.preprocessing.image import ImageDataGenerator


train_datagen = ImageDataGenerator(
      rescale=1./255,
      rotation_range=20,
      width_shift_range=0.2,
      height_shift_range=0.2,
      horizontal_flip=True,
      fill_mode='nearest')
 
validation_datagen = ImageDataGenerator(rescale=1./255)
 
# Change the batchsize according to your system RAM
train_batchsize = 50
val_batchsize = 10
 
train_generator = train_datagen.flow_from_directory(
         '../../data/deep_learn/train/',
        target_size=(image_size, image_size),
        batch_size=train_batchsize,
        class_mode='categorical')
 
validation_generator = validation_datagen.flow_from_directory(
         '../../data/deep_learn/teste/',
        target_size=(image_size, image_size),
        batch_size=val_batchsize,
        class_mode='categorical',
        shuffle=True)
# Out:
# Found 1500 images belonging to 2 classes.
# Found 500 images belonging to 2 classes.

# %%
model.compile(loss='categorical_crossentropy',
              optimizer=optimizers.RMSprop(lr=1e-4),
              #optimizer='sgd',
              metrics=['acc'])

# %%
# Train the model
history = model.fit_generator(
      train_generator,
      steps_per_epoch=train_generator.samples/train_generator.batch_size ,
      epochs=20,
      validation_data=validation_generator,
      validation_steps=validation_generator.samples/validation_generator.batch_size,verbose=1)
# Out:
# Epoch 1/20
# 30/30 [==============================] - 92s 3s/step - loss: 2.2890 - acc: 0.6753 - val_loss: 3.0539 - val_acc: 0.6180
# Epoch 2/20
# 30/30 [==============================] - 78s 3s/step - loss: 0.5322 - acc: 0.8420 - val_loss: 1.2850 - val_acc: 0.7960
# Epoch 3/20
# 30/30 [==============================] - 77s 3s/step - loss: 0.3321 - acc: 0.8973 - val_loss: 0.3122 - val_acc: 0.9340
# Epoch 4/20
# 30/30 [==============================] - 77s 3s/step - loss: 0.3600 - acc: 0.9000 - val_loss: 0.9974 - val_acc: 0.8600
# Epoch 5/20
# 30/30 [==============================] - 78s 3s/step - loss: 0.2361 - acc: 0.9300 - val_loss: 0.6295 - val_acc: 0.9060
# Epoch 6/20
# 30/30 [==============================] - 78s 3s/step - loss: 0.2332 - acc: 0.9393 - val_loss: 0.4039 - val_acc: 0.9340
# Epoch 7/20
# 30/30 [==============================] - 78s 3s/step - loss: 0.2801 - acc: 0.9287 - val_loss: 0.6602 - val_acc: 0.8980
# Epoch 8/20
# 30/30 [==============================] - 78s 3s/step - loss: 0.2733 - acc: 0.9380 - val_loss: 0.2181 - val_acc: 0.9640
# Epoch 9/20
# 30/30 [==============================] - 78s 3s/step - loss: 0.2544 - acc: 0.9393 - val_loss: 0.2252 - val_acc: 0.9640
# Epoch 10/20
# 30/30 [==============================] - 78s 3s/step - loss: 0.1707 - acc: 0.9580 - val_loss: 0.4433 - val_acc: 0.9440
# Epoch 11/20
# 30/30 [==============================] - 78s 3s/step - loss: 0.1848 - acc: 0.9513 - val_loss: 0.3448 - val_acc: 0.9540
# Epoch 12/20
# 30/30 [==============================] - 79s 3s/step - loss: 0.1678 - acc: 0.9580 - val_loss: 0.2437 - val_acc: 0.9660
# Epoch 13/20
# 30/30 [==============================] - 79s 3s/step - loss: 0.1612 - acc: 0.9620 - val_loss: 0.2236 - val_acc: 0.9800
# Epoch 14/20
# 30/30 [==============================] - 78s 3s/step - loss: 0.2377 - acc: 0.9553 - val_loss: 0.5407 - val_acc: 0.9360
# Epoch 15/20
# 30/30 [==============================] - 78s 3s/step - loss: 0.2251 - acc: 0.9547 - val_loss: 0.1903 - val_acc: 0.9740
# Epoch 16/20
# 30/30 [==============================] - 78s 3s/step - loss: 0.1901 - acc: 0.9613 - val_loss: 0.2904 - val_acc: 0.9680
# Epoch 17/20
# 30/30 [==============================] - 78s 3s/step - loss: 0.1201 - acc: 0.9733 - val_loss: 0.2566 - val_acc: 0.9720
# Epoch 18/20
# 30/30 [==============================] - 79s 3s/step - loss: 0.2730 - acc: 0.9473 - val_loss: 0.2528 - val_acc: 0.9680
# Epoch 19/20
# 30/30 [==============================] - 79s 3s/step - loss: 0.1855 - acc: 0.9613 - val_loss: 0.3010 - val_acc: 0.9620
# Epoch 20/20
# 30/30 [==============================] - 78s 3s/step - loss: 0.2067 - acc: 0.9593 - val_loss: 0.1930 - val_acc: 0.9700

# %%
import matplotlib.pyplot as plt

acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']
 
epochs = range(len(acc))
 
plt.plot(epochs, acc, 'b', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()
 
plt.figure()
 
plt.plot(epochs, loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
 
plt.show()

# %%
# Create a generator for prediction
validation_generator = validation_datagen.flow_from_directory(
         '../../data/deep_learn/teste/',
        target_size=(image_size, image_size),
        batch_size=val_batchsize,
        class_mode='categorical',
        shuffle=False)
# Out:
# Found 500 images belonging to 2 classes.

# %%
 
# Get the filenames from the generator
fnames = validation_generator.filenames
 
# Get the ground truth from generator
ground_truth = validation_generator.classes
 
# Get the label to class mapping from the generator
label2index = validation_generator.class_indices
 
# Getting the mapping from class index to class label
idx2label = dict((v,k) for k,v in label2index.items())
 
# Get the predictions from the model using the generator
predictions = model.predict_generator(validation_generator, steps=validation_generator.samples/validation_generator.batch_size,verbose=1)
predicted_classes = np.argmax(predictions,axis=1)
 
errors = np.where(predicted_classes != ground_truth)[0]
print("No of errors = {}/{}".format(len(errors),validation_generator.samples))
 
# Show the errors
for i in range(len(errors)):
    pred_class = np.argmax(predictions[errors[i]])
    pred_label = idx2label[pred_class]
     
    title = 'Original label:{}, Prediction :{}, confidence : {:.3f}'.format(
        fnames[errors[i]].split('/')[0],
        pred_label,
        predictions[errors[i]][pred_class])
     
    original = load_img('{}/{}'.format( '../../data/deep_learn/teste/',fnames[errors[i]]))
    plt.figure(figsize=[7,7])
    plt.axis('off')
    plt.title(title)
    plt.imshow(original)
    plt.show()
# Out:
# 50/50 [==============================] - 25s 493ms/step
# No of errors = 15/500

# %%
early_stop = EarlyStopping(monitor='val_loss', min_delta=0, patience=3, verbose=1, mode='auto')


# Create the model
model = models.Sequential()
 
# Add the vgg convolutional base model
model.add(resnet_conv)
 
# Add new layers
model.add(layers.Flatten())
model.add(layers.Dense(1024, activation='relu'))
model.add(layers.Dropout(0.75))
model.add(layers.Dense(2, activation='softmax'))
 
# Show a summary of the model. Check the number of trainable parameters
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inception_resnet_v2 (Model)  (None, 5, 5, 1536)        54336736
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 38400)             0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1024)              39322624
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 2)                 2050
# =================================================================
# Total params: 93,661,410
# Trainable params: 42,521,090
# Non-trainable params: 51,140,320
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy',
              #optimizer=optimizers.RMSprop(lr=1e-4),
              optimizer='sgd',
              metrics=['acc'])

# %%
# Train the model
history = model.fit_generator(
      train_generator,
      steps_per_epoch=train_generator.samples/train_generator.batch_size ,
      epochs=13,
      validation_data=validation_generator,
      validation_steps=validation_generator.samples/validation_generator.batch_size,verbose=1)
# Out:
# Epoch 1/13
# 30/30 [==============================] - 86s 3s/step - loss: 0.4588 - acc: 0.8573 - val_loss: 0.1341 - val_acc: 0.9580
# Epoch 2/13
# 30/30 [==============================] - 74s 2s/step - loss: 0.1506 - acc: 0.9460 - val_loss: 0.1089 - val_acc: 0.9660
# Epoch 3/13
# 30/30 [==============================] - 74s 2s/step - loss: 0.0885 - acc: 0.9673 - val_loss: 0.3059 - val_acc: 0.9220
# Epoch 4/13
# 30/30 [==============================] - 75s 2s/step - loss: 0.1125 - acc: 0.9573 - val_loss: 0.3231 - val_acc: 0.9140
# Epoch 5/13
# 30/30 [==============================] - 75s 3s/step - loss: 0.0922 - acc: 0.9647 - val_loss: 0.2611 - val_acc: 0.9360
# Epoch 6/13
# 30/30 [==============================] - 76s 3s/step - loss: 0.0936 - acc: 0.9627 - val_loss: 0.1280 - val_acc: 0.9680
# Epoch 7/13
# 30/30 [==============================] - 75s 3s/step - loss: 0.1033 - acc: 0.9660 - val_loss: 0.1815 - val_acc: 0.9540
# Epoch 8/13
# 30/30 [==============================] - 76s 3s/step - loss: 0.0964 - acc: 0.9673 - val_loss: 0.1028 - val_acc: 0.9720
# Epoch 9/13
# 30/30 [==============================] - 76s 3s/step - loss: 0.0774 - acc: 0.9693 - val_loss: 0.1737 - val_acc: 0.9580
# Epoch 10/13
# 30/30 [==============================] - 76s 3s/step - loss: 0.0811 - acc: 0.9733 - val_loss: 0.2394 - val_acc: 0.9420
# Epoch 11/13
# 30/30 [==============================] - 76s 3s/step - loss: 0.0889 - acc: 0.9693 - val_loss: 0.1420 - val_acc: 0.9620
# Epoch 12/13
# 30/30 [==============================] - 77s 3s/step - loss: 0.0920 - acc: 0.9660 - val_loss: 0.3318 - val_acc: 0.9240
# Epoch 13/13
# 30/30 [==============================] - 76s 3s/step - loss: 0.0937 - acc: 0.9680 - val_loss: 0.3632 - val_acc: 0.9200

# %%
model.summary()
model.pop()
model.pop()
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inception_resnet_v2 (Model)  (None, 5, 5, 1536)        54336736
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 38400)             0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1024)              39322624
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 2)                 2050
# =================================================================
# Total params: 93,661,410
# Trainable params: 42,521,090
# Non-trainable params: 51,140,320
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inception_resnet_v2 (Model)  (None, 5, 5, 1536)        54336736
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 38400)             0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1024)              39322624
# =================================================================
# Total params: 93,661,410
# Trainable params: 42,521,090
# Non-trainable params: 51,140,320
# _________________________________________________________________
# /usr/local/lib/python2.7/dist-packages/keras/engine/training.py:478: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'

# %%
model.save('estomato_InceptionResNetV2_final.h5')
